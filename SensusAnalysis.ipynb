# %%
import pandas as pd

# %%
df_acc = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\S3DataPickled\AccelerometerDatum.p')
df_manet = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\S3DataPickled\MagnetometerDatum.p')
df_part = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\S3DataPickled\ParticipationReportDatum.p')
df_prot = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\S3DataPickled\ProtocolStateDatum.p')

# %%
df_acc.to_csv('accelerator.csv')
df_acc.head()
# Out:
#    Accuracy  BuildId          DeviceId DeviceManufacturer DeviceModel  \
# 0       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 1       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 2       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 3       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 4       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
#
#                                      Id  Latitude LocalOffsetFromUTC  \
# 0  ef5e6ac3-9f8c-4a3b-9f97-fae0c5b98ffa       NaN          -04:00:00
# 1  ef5e6ac3-9f8c-4a3b-9f97-fae0c5b98ffa       NaN          -04:00:00
# 2  d21a2777-86c4-4498-bf48-ed003a8ca848       NaN          -04:00:00
# 3  d21a2777-86c4-4498-bf48-ed003a8ca848       NaN          -04:00:00
# 4  af55ec37-2524-4d13-ab55-6e39496c77e3       NaN          -04:00:00
#
#    Longitude             OS  ...  Formatted Timestamp  Year Month Day Hour  \
# ...

# %%
df_manet.to_csv('MagnetometerDatum.csv')
df_manet.head()
# Out:
#    Accuracy  BuildId  Decibels          DeviceId DeviceManufacturer  \
# 0       NaN  15.18.0       NaN  4882779d8b191114            samsung
# 1       NaN  15.18.0       NaN  4882779d8b191114            samsung
# 2       NaN  15.18.0       NaN  4882779d8b191114            samsung
# 3       NaN  15.18.0       NaN  4882779d8b191114            samsung
# 4       NaN  15.18.0       NaN  4882779d8b191114            samsung
#
#   DeviceModel                                    Id  Latitude  \
# 0    a7y18lte  22cfd6ac-b1de-4b43-b22f-0f608ca59ad2       NaN
# 1    a7y18lte  22cfd6ac-b1de-4b43-b22f-0f608ca59ad2       NaN
# 2    a7y18lte  bd3ff9ab-a7b0-4258-a20d-550e98f82db0       NaN
# 3    a7y18lte  bd3ff9ab-a7b0-4258-a20d-550e98f82db0       NaN
# 4    a7y18lte  50fdff95-39c0-4b3b-ace7-0fc3a03d21a3       NaN
#
#   LocalOffsetFromUTC  Longitude  ...  Formatted Timestamp  Year Month Day  \
# 0          -04:00:00        NaN  ...  04/23/2020 17:05:57  2020     4  23
# ...

# %%
df_part.to_csv('ParticipationReportDatum.csv')
df_part.head()
# Out:
#    BuildId          DeviceId DeviceManufacturer DeviceModel  \
# 0  15.18.0  4882779d8b191114            samsung    a7y18lte
# 1  15.18.0  4882779d8b191114            samsung    a7y18lte
# 2  15.18.0  4882779d8b191114            samsung    a7y18lte
# 3  15.18.0  4882779d8b191114            samsung    a7y18lte
# 4  15.18.0  4882779d8b191114            samsung    a7y18lte
#
#                                      Id LocalOffsetFromUTC OperatingSystem  \
# 0  246ed020-1a77-4e30-bb97-779f2b3e227a          -04:00:00       Android P
# 1  246ed020-1a77-4e30-bb97-779f2b3e227a          -04:00:00       Android P
# 2  11ce0582-5cdf-4934-af0c-764989cb9c2c          -04:00:00       Android P
# 3  11ce0582-5cdf-4934-af0c-764989cb9c2c          -04:00:00       Android P
# 4  625c0095-068a-4c84-b58f-5d20b6da3f02          -04:00:00       Android P
#
#   ParticipantId                            ProtocolId  \
# 0          None  916241e1-bfc9-4809-9401-4dd81493bef3
# ...

# %%
df_prot.to_csv('ProtocolStateDatum.csv')
df_prot.head()
# Out:
#    Accuracy  BuildId          DeviceId DeviceManufacturer DeviceModel  \
# 0       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 1       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 2       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 3       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
# 4       NaN  15.18.0  4882779d8b191114            samsung    a7y18lte
#
#                                      Id  Latitude LocalOffsetFromUTC  \
# 0  171ecd47-4f3f-45a6-859b-d21662d7360b       NaN          -04:00:00
# 1  171ecd47-4f3f-45a6-859b-d21662d7360b       NaN          -04:00:00
# 2  af27f29c-149a-4c98-a670-577a7d1c3b5e       NaN          -04:00:00
# 3  af27f29c-149a-4c98-a670-577a7d1c3b5e       NaN          -04:00:00
# 4  07258f76-97cc-465e-a714-9fb3a8557754       NaN          -04:00:00
#
#    Longitude             OS  ...  Formatted Timestamp  Year Month Day Hour  \
# ...

# %%
df_acc.to_csv("AccelerometerDatum.csv")
print("Data posted to file")

# %%
df_attd = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\AttitudeDatum.p')
df_gyro = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\GyroscopeDatum.p')
df_lnrac = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\LinearAccelerationDatum.p')
df_loc = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\LocationDatum.p')

df_log = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\LogDatum.p')
df_mag = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\MagnetometerDatum.p')
df_scr = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\ScriptStateDatum.p')
df_speed = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\SunilDataPickled_old\SpeedDatum.p')

# %%
df_attd.to_csv('Attitude.csv')
df_gyro.to_csv('Gyroscope.csv')
df_lnrac.to_csv('Lnracc.csv') 
df_loc.to_csv('Location.csv') 
df_log.to_csv('Logdatum.csv') 
df_mag.to_csv('Magnet.csv')
df_scr.to_csv('Script.csv') 
df_speed.to_csv('speed.csv')

# %%
df_acc1 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\AccelerationPickled\AccelerometerDatum.p')
df_acc2 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\AccelerationPickled\ProtocolStateDatum.p')

#df_gps = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\GPSPickled\AccelerometerDatum.p')
#df_comp = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\CompassHeadingPickled\ProtocolStateDatum.p')
#
#df_battery = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BatteryLevelPickled\ProtocolStateDatum.p')

# %%
df_acc1.to_csv('Acceleration-1.csv')
df_acc2.to_csv('Acceleration-2.csv')
#df_gps.to_csv('GPS.csv')
#df_comp.to_csv('compas.csv')

# %%
df_battery.to_csv('battery.csv')

# %%
df_comp1 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\CompassHeadingPickled\AccelerometerDatum.p')
df_comp2 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\CompassHeadingPickled\CompassDatum.p')
df_comp3 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\CompassHeadingPickled\LinearAccelerationDatum.p')
df_comp4 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\CompassHeadingPickled\ProtocolStateDatum.p')

# %%
df_comp1.to_csv('compas1.csv', index='False')
df_comp2.to_csv('compas2.csv', index='False')
df_comp3.to_csv('compas3.csv', index='False')
df_comp4.to_csv('compas4.csv', index='False')

# %%
df_battery1 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BatteryLevelPickled\BatteryDatum.p')
df_battery2 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BatteryLevelPickled\CompassDatum.p')
df_battery3 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BatteryLevelPickled\ProtocolStateDatum.p')

# %%
df_battery1.to_csv('battery1.csv')
df_battery2.to_csv('battery2.csv')
df_battery3.to_csv('battery3.csv')

# %%
df_bluetooth1 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BluetoothPickled\AccelerometerDatum.p')
df_bluetooth2 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BluetoothPickled\BatteryDatum.p')
df_bluetooth3 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BluetoothPickled\CompassDatum.p')
df_bluetooth4 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BluetoothPickled\LinearAccelerationDatum.p')
df_bluetooth5 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\BluetoothPickled\ProtocolStateDatum.p')

# %%
df_bluetooth1.to_csv('bluetooth1.csv', index='False')
df_bluetooth2.to_csv('bluetooth2.csv', index='False')
df_bluetooth3.to_csv('bluetooth3.csv', index='False')
df_bluetooth4.to_csv('bluetooth4.csv', index='False')
df_bluetooth5.to_csv('bluetooth5.csv', index='False')

# %%
#df_gps1 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\GPSPickled\AccelerometerDatum.p')
df_gpsloc = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\GPSPickled\LocationDatum.p')
df_gps3 = pd.read_pickle(r'E:\MS_studyProcess\UNCC-Study\spring-2020\6160-BigDataDesign\Challenge-2\GPSPickled\ProtocolStateDatum.p')

# %%
df_gpsloc.to_csv('gpsloc1.csv', index='False')
df_gps3.to_csv('GPS3.csv', index='False')
